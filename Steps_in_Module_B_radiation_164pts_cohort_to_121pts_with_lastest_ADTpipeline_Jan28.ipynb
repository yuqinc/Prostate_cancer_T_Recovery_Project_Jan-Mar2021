# %% [markdown]
# # README.md
#
# # Research question: What’s the initial ADT use time window for each patient?
#
# ## Table of Contents
# * [Read data, clean up and get stats](#first-bullet)
# * [Detele the lines labeled as "deleted" in "comment"](#second-bullet)
# * [Keep only the ADT drugs](#third-bullet)
# * [Identify the initial ADT use window](#fourth-bullet)
# * [Output and plot data](#fifth-bullet)

# %% [markdown]
# ###be careful of unreviewed cells; uncertainty
# ###be careful of the cells that need discussion cell style as "input"
# ###validate and crosscheck each step
# ###fix date like may-2014/datetime format

# %% [markdown]
# # Read data, clean up and get stats <a class="anchor" id="first-bullet"></a>

# %%
import numpy as np
import pandas as pd
import sys, getopt
import csv
from datetime import datetime
import itertools

import matplotlib.pyplot as plt
from matplotlib import pyplot
from pylab import *

# %matplotlib inline  
import seaborn as sns

# %%
df1=pd.read_excel("../A3test.xls", header=0)

# %%
df1[:5]
# Out:
#    person_id generic_drug_name    source  \
# 0       12.0        Leuprolide  Medtable
# 1       18.0         Goserelin  Medtable
# 2       18.0         Degarelix  Medtable
# 3       25.0        Leuprolide  Medtable
# 4       25.0        Leuprolide     Notes
#
#                                             evidence match_string  start_year  \
# 0                                                NaN          NaN      2013.0
# 1                                                NaN          NaN      2013.0
# 2                                                NaN          NaN      2013.0
# 3                                                NaN          NaN      2013.0
# 4  The patient was started on bicalutamide x 2 we...          NaN      2013.0
#
#    start_month  start_day  end_year  end_month  end_day           start_date  \
# 0          5.0        6.0    2013.0        5.0      6.0  2013-05-06 00:00:00
# 1         12.0        9.0    2014.0        3.0     13.0  2013-12-09 00:00:00
# 2         11.0       12.0    2013.0       11.0     12.0  2013-11-12 00:00:00
# 3         11.0       12.0    2014.0        2.0     18.0                  NaN
# 4          8.0        NaN       NaN        NaN      NaN  2013-08-01 00:00:00
#
#               end_date imputed_stage   comment  \
# 0  2013-05-06 00:00:00           NaN  reviewed
# 1  2014-03-13 00:00:00           NaN  reviewed
# 2  2013-11-12 00:00:00           NaN  reviewed
# 3  2014-02-18 00:00:00           NaN  reviewed
# 4                  NaN           NaN     added
#
#                                               reason  Unnamed: 16  \
# 0                                                NaN          NaN
# 1                                                NaN          NaN
# 2                                                NaN          NaN
# 3  The starting date is 8/2013, before the notes ...          NaN
# 4                                                NaN          NaN
#
#    Unnamed: 17  Unnamed: 18 Unnamed: 19
# 0          NaN          NaN         NaN
# 1          NaN          NaN         NaN
# 2          NaN          NaN         NaN
# 3          NaN          NaN         NaN
# 4          NaN          NaN         NaN

# %%
index_list=df1.columns
index_list
# Out:
# Index(['person_id', 'generic_drug_name', 'source', 'evidence', 'match_string',
#        'start_year', 'start_month', 'start_day', 'end_year', 'end_month',
#        'end_day', 'start_date', 'end_date', 'imputed_stage', 'comment',
#        'reason', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19'],
#       dtype='object')

# %%
#delete empty columns
print(df1.shape)
del_col=['evidence', 'match_string',
       'start_year', 'start_month', 'start_day', 'end_year', 'end_month',
       'end_day', 'imputed_stage','reason', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19']

for col in del_col:
    del df1[col]
print(df1.shape)
# Out:
# (656, 20)
# (656, 6)

# %%
#change person_id to int
df1['person_id']=df1['person_id'].values.astype(int)

# %%
#df_test=df1[(df1["start_date"] == "may-2014")]
#df_test (this was taken care of in the spreadsheets; it was inputed as timedate format)

# %%
#value=df1.at[483,"start_date"]
#print(value)
#df1.at[483,"start_date"]="2014-05-01 00:00:00"
#value=df1.at[483,"start_date"]
#print(value)

# %%
df1[:5]
# Out:
#    person_id generic_drug_name    source           start_date  \
# 0         12        Leuprolide  Medtable  2013-05-06 00:00:00
# 1         18         Goserelin  Medtable  2013-12-09 00:00:00
# 2         18         Degarelix  Medtable  2013-11-12 00:00:00
# 3         25        Leuprolide  Medtable                  NaN
# 4         25        Leuprolide     Notes  2013-08-01 00:00:00
#
#               end_date   comment
# 0  2013-05-06 00:00:00  reviewed
# 1  2014-03-13 00:00:00  reviewed
# 2  2013-11-12 00:00:00  reviewed
# 3  2014-02-18 00:00:00  reviewed
# 4                  NaN     added

# %%
#find out number of pts to start with

df_adt_rows = df1[df1['generic_drug_name'].isin(ADT_lib)]
df_nonadt_rows = df1[~df1['generic_drug_name'].isin(ADT_lib)]

#group by pt; get list of pts
df1_by_pt=df1.groupby(["person_id"]).size().reset_index(name='counts')
cohort_pt_list=df1_by_pt["person_id"].to_list()
print("total number of pts: ")
print(len(cohort_pt_list))
# Out:
# total number of pts:
# 164

# %%
#remove empty cells 
df1['comment'].replace('', np.nan, inplace=True)
df1.dropna(subset=['comment'], inplace=True)
df1['start_date'].replace(u'\xa0', u'', inplace=True)
df1['end_date'].replace(u'\xa0', u'', inplace=True)
df1['start_date'].replace('', np.nan, inplace=True)
df1['end_date'].replace('', np.nan, inplace=True)

# %%
#found out the number of pts
df_ptinfo=df1.groupby(["person_id"]).size().reset_index(name='counts')
print(df_ptinfo.shape)
# Out:
# (125, 2)

# %% [markdown]
# # Detele the lines labeled as "deleted" in "comment" <a class="anchor" id="second-bullet"></a>

# %%
deleted_list=[]
reviewed_list=[]
added_list=[]

for ind in df1.index:
    if (df1['comment'][ind]=='deleted'): 
        deleted_list.append(ind)  
    if (df1['comment'][ind]=='reviewed'): 
        reviewed_list.append(ind)  
    if (df1['comment'][ind]=='added'): 
        added_list.append(ind)

# %%
total_lines=len(deleted_list)+len(reviewed_list)+len(added_list)

print("Total number lines is: " +str(total_lines))
print("Number of deleted lines is: " +str(len(deleted_list)),  "; Percentage is "  +str(100*round(len(deleted_list)/total_lines,3)))
print("Number of reviewed lines is: " +str(len(reviewed_list)), "; Percentage is " +str(100*round(len(reviewed_list)/total_lines,1)))
print("Number of added lines is: " +str(len(added_list)),   "; Percentage is "     +str(100*round(len(added_list)/total_lines,3)))
# Out:
# Total number lines is: 396
# Number of deleted lines is: 41 ; Percentage is 10.4
# Number of reviewed lines is: 223 ; Percentage is 60.0
# Number of added lines is: 132 ; Percentage is 33.300000000000004

# %%
###delete the lines that has deleted in the column "comment"
###the most impotant info is on the patient level
print(df1.shape)
for ind in deleted_list:
    df1.drop(index=ind,inplace=True)
print(df1.shape)
# Out:
# (414, 6)
# (373, 6)

# %% [markdown]
# # Keep only the ones that are ADTs <a class="anchor" id="third-bullet"></a>

# %%
ADT_lib=["Leuprolide", "Degarelix", "Goserelin", "Triptorelin", "Histrelin", 
         "leuprolide", "degarelix", "goserelin", "triptorelin", "histrelin"]

# %%
#subset dataframes 

#approach 1

df_adt_rows = df1[df1['generic_drug_name'].isin(ADT_lib)]
df_nonadt_rows = df1[~df1['generic_drug_name'].isin(ADT_lib)]

#group by pt; get list of pts
adt_grouped_by_pt=df_adt_rows.groupby(["person_id"]).size().reset_index(name='counts')
adt_pt_list=adt_grouped_by_pt["person_id"].to_list()

nonadt_grouped_by_pt=df_nonadt_rows.groupby(["person_id"]).size().reset_index(name='counts')
nonadt_pt_list=nonadt_grouped_by_pt["person_id"].to_list()

#bad list= pts have non adt drugs but no adt drugs ever
#bad_pt_list=[x for x in nonadt_pt_list if x not in adt_pt_list]
print("pts that have adt")
print(len(adt_pt_list))
# Out:
# pts that have adt
# 121
# pts that dont have adt
# 2

# %%
#approach 2
not_adt_list=[]

#get the list
for ind in df1.index:
    if (df1['generic_drug_name'][ind] not in ADT_lib): 
        not_adt_list.append(ind) 
        
#delete the lines in the list
for ind in not_adt_list:
    df1.drop(index=ind,inplace=True)
    
print("Number of lines with a non ADT drug is ", len(not_adt_list))
print("shape of cleaned dataframe")
print(df1.shape)
df1.reset_index()

df_adt=df1
# Out:
# Number of lines with a non ADT drug is  122
# shape of cleaned dataframe
# (251, 6)

# %%
##check column start_date, end_date time format is correct
for i in df1.index:
    #print(pd.to_datetime(df1['start_date'][i], format='%d-%b-%Y'))
    #print(df1['start_date'][i])
    print(pd.to_datetime(df1['start_date'][i], format='%d-%b-%Y'))
# Out:
# 2013-05-06 00:00:00
# 2013-12-09 00:00:00
# 2013-11-12 00:00:00
# NaT
# 2013-08-01 00:00:00
# 2014-11-26 00:00:00
# NaT
# 2015-11-18 00:00:00
# 2013-03-12 00:00:00
# NaT
# 2013-02-15 00:00:00
# 2017-08-01 00:00:00
# 2017-09-13 00:00:00
# 2013-07-02 00:00:00
# NaT
# 2015-06-18 00:00:00
# 2018-05-29 00:00:00
# 2017-07-12 00:00:00
# 2017-06-14 00:00:00
# 2014-05-21 00:00:00
# NaT
# 2020-04-15 00:00:00
# NaT
# 2018-07-03 00:00:00
# NaT
# NaT
# 2018-01-10 00:00:00
# NaT
# NaT
# 2017-01-11 00:00:00
# 2017-10-30 00:00:00
# 2018-04-25 00:00:00
# 2017-11-30 00:00:00
# 2015-06-18 00:00:00
# 2017-11-06 00:00:00
# 2018-09-12 00:00:00
# NaT
# 2015-01-30 00:00:00
# NaT
# 2015-12-03 00:00:00
# NaT
# 2015-06-15 00:00:00
# 2015-09-03 00:00:00
# 2016-08-19 00:00:00
# 2017-10-30 00:00:00
# 2018-02-07 00:00:00
# NaT
# 2016-03-15 00:00:00
# NaT
# 2015-01-30 00:00:00
# 2015-03-03 00:00:00
# 2017-09-14 00:00:00
# NaT
# 2016-08-31 00:00:00
# 2018-05-17 00:00:00
# 2018-04-17 00:00:00
# 2016-02-08 00:00:00
# NaT
# 2019-09-10 00:00:00
# NaT
# 2016-06-29 00:00:00
# 2016-08-17 00:00:00
# NaT
# 2017-02-27 00:00:00
# 2018-06-13 00:00:00
# 2018-08-08 00:00:00
# 2018-07-12 00:00:00
# 2018-04-06 00:00:00
# 2017-09-18 00:00:00
# NaT
# 2015-12-02 00:00:00
# 2015-11-05 00:00:00
# NaT
# 2019-11-27 00:00:00
# 2016-01-24 00:00:00
# 2017-01-24 00:00:00
# 2013-10-22 00:00:00
# 2017-10-30 00:00:00
# NaT
# 2019-08-26 00:00:00
# 2017-10-02 00:00:00
# 2014-03-05 00:00:00
# NaT
# NaT
# 2012-10-31 00:00:00
# 2018-04-03 00:00:00
# NaT
# 2016-08-31 00:00:00
# 2016-10-05 00:00:00
# 2017-02-24 00:00:00
# NaT
# 2018-10-13 00:00:00
# NaT
# NaT
# 2016-03-16 00:00:00
# 2016-04-25 00:00:00
# 2013-08-16 00:00:00
# NaT
# 2013-10-21 00:00:00
# 2017-02-24 00:00:00
# NaT
# 2018-03-12 00:00:00
# 2019-08-30 00:00:00
# 2020-07-06 00:00:00
# NaT
# 2020-05-20 00:00:00
# NaT
# 2018-01-02 00:00:00
# NaT
# 2015-05-13 00:00:00
# NaT
# 2015-07-27 00:00:00
# 2015-08-24 00:00:00
# NaT
# 2012-07-03 00:00:00
# 2018-05-31 00:00:00
# 2018-06-28 00:00:00
# 2018-07-13 00:00:00
# NaT
# 2017-03-28 00:00:00
# NaT
# 2019-06-27 00:00:00
# 2020-02-07 00:00:00
# NaT
# 2017-01-30 00:00:00
# 2017-08-21 00:00:00
# NaT
# 2016-09-29 00:00:00
# 2018-03-27 00:00:00
# NaT
# 2016-08-31 00:00:00
# NaT
# 2018-09-10 00:00:00
# NaT
# 2017-09-13 00:00:00
# 2017-09-12 00:00:00
# 2017-08-04 00:00:00
# 2017-01-11 00:00:00
# 2013-11-06 00:00:00
# NaT
# 2016-12-22 00:00:00
# 2016-03-01 00:00:00
# 2016-02-03 00:00:00
# 2018-04-12 00:00:00
# 2018-07-10 00:00:00
# 2017-08-09 00:00:00
# 2017-10-09 00:00:00
# 2015-07-24 00:00:00
# 2015-06-26 00:00:00
# 2018-04-16 00:00:00
# 2012-05-29 00:00:00
# 2012-07-03 00:00:00
# NaT
# 2017-07-14 00:00:00
# 2017-06-09 00:00:00
# 2017-12-20 00:00:00
# 2017-11-28 00:00:00
# 2017-10-31 00:00:00
# 2018-06-25 00:00:00
# NaT
# 2018-05-25 00:00:00
# 2017-01-18 00:00:00
# NaT
# 2015-06-01 00:00:00
# 2018-06-01 00:00:00
# 2017-05-31 00:00:00
# NaT
# 2018-06-22 00:00:00
# 2015-09-16 00:00:00
# NaT
# 2019-02-15 00:00:00
# NaT
# 2012-04-03 00:00:00
# 2012-02-28 00:00:00
# 2013-06-05 00:00:00
# 2018-05-02 00:00:00
# 2018-03-30 00:00:00
# 2018-03-22 00:00:00
# 2018-02-22 00:00:00
# NaT
# 2018-02-28 00:00:00
# NaT
# 2018-01-30 00:00:00
# 2015-09-23 00:00:00
# 2016-07-15 00:00:00
# NaT
# 2018-08-22 00:00:00
# 2014-05-01 00:00:00
# NaT
# 2016-02-17 00:00:00
# NaT
# 2017-10-23 00:00:00
# NaT
# 2015-04-09 00:00:00
# 2015-05-12 00:00:00
# 2014-05-05 00:00:00
# 2015-09-29 00:00:00
# NaT
# 2017-08-25 00:00:00
# NaT
# NaT
# 2015-08-31 00:00:00
# NaT
# NaT
# 2015-07-09 00:00:00
# 2016-05-18 00:00:00
# NaT
# NaT
# 2015-01-23 00:00:00
# 2017-01-17 00:00:00
# 2018-10-04 00:00:00
# 2020-02-24 00:00:00
# 2018-06-08 00:00:00
# 2018-03-27 00:00:00
# 2018-02-21 00:00:00
# 2012-12-05 00:00:00
# NaT
# 2018-08-03 00:00:00
# 2017-04-17 00:00:00
# NaT
# 2017-11-06 00:00:00
# NaT
# 2019-10-30 00:00:00
# NaT
# 2016-04-01 00:00:00
# 2016-03-04 00:00:00
# 2018-04-03 00:00:00
# NaT
# NaT
# 2014-03-12 00:00:00
# NaT
# 2018-04-04 00:00:00
# 2014-06-01 00:00:00
# 2019-07-08 00:00:00
# NaT
# 2018-08-28 00:00:00
# 2018-06-21 00:00:00
# 2018-02-01 00:00:00
# NaT
# 2015-07-21 00:00:00
# 2015-06-23 00:00:00
# 2012-11-26 00:00:00
# NaT
# 2014-04-24 00:00:00
# NaT
# 2019-09-10 00:00:00
# 2016-01-07 00:00:00
# 2019-04-15 00:00:00
# 2015-10-07 00:00:00
# 2017-08-09 00:00:00
# 2017-09-13 00:00:00

# %%
###crosscheck
#not_adt_list
###spotcheck 
test2 = df1[(df1["person_id"] == 36062)]
test2
# Out:
#      person_id generic_drug_name    source           start_date  \
# 638      36062        Leuprolide  Medtable                  NaN
# 639      36062        Leuprolide     Notes  2014-04-24 00:00:00
# 640      36062         Degarelix  Medtable                  NaN
# 641      36062         Degarelix     Notes  2019-09-10 00:00:00
#
#                 end_date   comment
# 638  2016-06-07 00:00:00  reviewed
# 639                  NaN  reviewed
# 640  2020-05-07 00:00:00  reviewed
# 641                  NaN     added

# %%
df1[240:250]
# Out:
#      person_id generic_drug_name    source           start_date  \
# 632      34807         Degarelix     Notes  2015-06-23 00:00:00
# 635      35033         Degarelix  Medtable  2012-11-26 00:00:00
# 638      36062        Leuprolide  Medtable                  NaN
# 639      36062        Leuprolide     Notes  2014-04-24 00:00:00
# 640      36062         Degarelix  Medtable                  NaN
# 641      36062         Degarelix     Notes  2019-09-10 00:00:00
# 643      36369        Leuprolide  Medtable  2016-01-07 00:00:00
# 646      36369         Degarelix     Notes  2019-04-15 00:00:00
# 647      36508        Leuprolide  Medtable  2015-10-07 00:00:00
# 653      36535         Degarelix     Notes  2017-08-09 00:00:00
#
#                 end_date   comment
# 632                  NaN  reviewed
# 635  2012-11-26 00:00:00  reviewed
# 638  2016-06-07 00:00:00  reviewed
# 639                  NaN  reviewed
# 640  2020-05-07 00:00:00  reviewed
# 641                  NaN     added
# 643  2016-06-23 00:00:00  reviewed
# 646                  NaN     added
# 647  2016-07-11 00:00:00  reviewed
# 653                  NaN  reviewed

# %% [markdown]
# # Identify the initial ADT use window <a class="anchor" id="forth-bullet"></a>

# %%
# Group by person_id
df2=df1.groupby(["person_id"]).size().reset_index(name='counts')
list_pts=df2["person_id"].to_list()

# %%
print("number of pts is:")
print(len(list_pts))
# Out:
# number of pts is:
# 121

# %%
df2.reset_index
df2.shape
# Out:
# (121, 2)

# %%
df2.index
df2['index1'] = df2.index

# %%
df2.columns
# Out:
# Index(['person_id', 'counts', 'index1'], dtype='object')

# %%
df2[['index1','counts']]
# Out:
#      index1  counts
# 0         0       1
# 1         1       2
# 2         2       2
# 3         3       2
# 4         4       1
# ..      ...     ...
# 116     116       1
# 117     117       4
# 118     118       2
# 119     119       1
# 120     120       2
#
# [121 rows x 2 columns]

# %%
sns.set_style("darkgrid")
sns.set_context("poster", font_scale=1.2, rc={"lines.linewidth": 2})

ax = df2.plot.bar(x='index1', y='counts', width=0.8, color='grey', rot=90, title ="LoT", figsize=(35, 5), legend=True, fontsize=12)

plt.tick_params(axis='x', labelsize=25)
plt.tick_params(axis='y', labelsize=25)
ax.set_xticks(np.arange(0, len(df2.index)+1, 5))
ax.set_xticklabels(np.arange(0, len(df2.index)+1, 5))
plt.xlabel("Person ID", fontsize=30, fontweight="bold")
plt.ylabel("Counts", fontsize=30,fontweight="bold")
plt.legend("")
plt.title("Rows of info per patient",fontsize=30,fontweight="bold")
#ax = df2[['index1'],['counts']].plot(kind='bar', title ="LoT", figsize=(30, 10), legend=True, fontsize=12)
# Out:
# Text(0.5, 1.0, 'Rows of info per patient')

# %%
#get the list of pts with max numbers of entries recording ADT usage
df2["counts"].max()
# Out:
# 6

# %%
df2[(df2["counts"] == 6)]
# Out:
#      person_id  counts  index1
# 60       19566       6      60
# 94       27966       6      94
# 101      30455       6     101

# %%
##spot check
df1[(df1["person_id"] == 12720)]
# Out:
#      person_id generic_drug_name source           start_date end_date comment
# 234      12720        Leuprolide  Notes  2012-10-31 00:00:00      NaN   added

# %%
i=12720

df_pt=df1[(df1["person_id"] == i)]
each_pt_drug_start = df_pt['start_date'].to_list()
each_pt_drug_end = df_pt['end_date'].to_list()

# %%
each_pt_drug_start
# Out:
# [datetime.datetime(2012, 10, 31, 0, 0)]

# %%
##get rid of nan
cleaned_a= [x for x in each_pt_drug_start if str(x) != 'NaN']
cleaned_aa= [x for x in cleaned_a if str(x) != 'nan']

cleaned_b= [x for x in each_pt_drug_end if str(x) != 'NaN']
cleaned_bb= [x for x in cleaned_b if str(x) != 'nan']

start_sorted_bin=sorted(cleaned_aa)
end_sorted_bin=sorted(cleaned_bb)

# %%
cleaned_aa
start_sorted_bin
# Out:
# [datetime.datetime(2012, 10, 31, 0, 0)]

# %%
start_with_2round=[]
start_with_1round=[]

#for a,b in itertools.combinations(list, 2):
    #print((str(a),str(b)))
a=start_sorted_bin[0]

for b in start_sorted_bin:
#find all adt starting dates after 6months of inital starting    
    if float(abs(a-b).days)>182.5:
        start_with_2round.append(a)
        start_with_2round.append(b)
    else:
        start_with_1round.append(a) 
#cleanup 
start_with_2round=start_with_2round[:2]

#get rid of repeated capturing for one round
cleanlist = []
for i in start_with_1round:
    if i not in cleanlist:
        cleanlist.append(i)
start_with_1round=cleanlist

# %%
if len(start_with_2round)==2:
    print(start_with_2round)
if (len(start_with_2round)<2) and (len(start_with_1round)==1):
    print(start_with_1round)
# Out:
# [datetime.datetime(2012, 10, 31, 0, 0)]

# %% [markdown]
# # Iterate

# %%
#spot check
df1[(df1["person_id"] == 12427)]
# Out:
#      person_id generic_drug_name source start_date             end_date  \
# 231      12427        Leuprolide  Notes        NaN  2020-07-22 00:00:00
#
#     comment
# 231   added

# %%
result_list=[]

for y in list_pts:
#for y in [27966,30455,19566,36062]:  
#for y in [33531,33555,33586]:  
#for y in [12427]:

    #subset the dataframe to each pt
    #get start dates and end dates to lists
    df_pt=df1[(df1["person_id"] == y)]
    
    each_pt_drug_start = df_pt['start_date'].to_list()
    each_pt_drug_end = df_pt['end_date'].to_list()

    ##get rid of nan
    cleaned_a=[]
    cleaned_a= [x for x in each_pt_drug_start if str(x) != 'NaN']
    cleaned_aa= [x for x in cleaned_a if str(x) != 'nan']
    cleaned_aaa= [x for x in cleaned_aa if str(x) != 'NaT']
    cleaned_b=[]
    cleaned_b= [x for x in each_pt_drug_end if str(x) != 'NaN']
    cleaned_bb= [x for x in cleaned_b if str(x) != 'nan']
    cleaned_bbb= [x for x in cleaned_bb if str(x) != 'NaT']

    ##get the date format right
    #startdatebin=[datetime.fromisoformat(str(x)) for x in cleaned_aa]
    #enddatebin=[datetime.fromisoformat(str(x)) for x in cleaned_bb]

    #sort 
    start_sorted_bin=sorted(cleaned_aaa)
    end_sorted_bin=sorted(cleaned_bbb)
    
    start_with_2round=[]
    start_with_1round=[]
    
    if(len(start_sorted_bin)==0):
        startdate='NaN'  
        if(len(end_sorted_bin)==0):
            enddate='NaN' 
        if(len(end_sorted_bin)>0):
            enddate=end_sorted_bin[0]
        
    if(len(start_sorted_bin)>0):
        a=start_sorted_bin[0]
        
        for b in start_sorted_bin:
        #find all adt starting dates after 6months of inital starting    
            if float(abs(a-b).days)>182.5:
                start_with_2round.append(a)
                start_with_2round.append(b)
            else:
                start_with_1round.append(a) 
        #cleanup 
        start_with_2round=start_with_2round[:2]

        #get rid of repeated capturing for one round
        cleanlist = []
        for i in start_with_1round:
            if i not in cleanlist:
                cleanlist.append(i)
        start_with_1round=cleanlist
        #print(cleanlist)
        enddateall=[]

    if len(end_sorted_bin)==0:
        enddate='NaN'
        if(len(start_sorted_bin)==0):
            startdate='NaN' 
        if(len(start_sorted_bin)>0):    
            startdate=start_with_1round[0]
        
    if len(end_sorted_bin)>0:
        for i in end_sorted_bin:
        #at least two rounds of ADTs
            if len(start_with_2round)==2:
                if(i>=sorted(start_with_2round)[0]) and (i<=sorted(start_with_2round)[1]):
                    startdate=sorted(start_with_2round)[0]
                    enddateall.append(i)
                    #print(enddateall)
                #pick the one that is most close to the 2nd adt starting date
                    if len(enddateall) == 0:
                        enddate='NaN' 
                    else:
                        enddate=enddateall[-1]

                if(i>sorted(start_with_2round)[0]) and (i>sorted(start_with_2round)[1]) and (len(enddateall) == 0):
                    startdate=sorted(start_with_2round)[0]
                    enddate='NaN'
                    #leave it as empty
        
        #only one round           
            if (len(start_with_2round)<2) and (len(start_with_1round)==1):
                if(i>=sorted(start_with_1round)[0]):
                    startdate=start_with_1round[0]
                    enddateall.append(i)
                    if len(enddateall) == 0:
                        enddate='NaN' 
                    else:
                        enddate=enddateall[-1]
                           
    print(y, startdate, enddate)
    result_per_pt=[y,startdate, enddate]
    result_list.append(result_per_pt)
# Out:
# 12 2013-05-06 00:00:00 2013-05-06 00:00:00
# 18 2013-11-12 00:00:00 2014-03-13 00:00:00
# 25 2013-08-01 00:00:00 2014-02-18 00:00:00
# 26 2014-11-26 00:00:00 2016-09-14 00:00:00
# 38 2015-11-18 00:00:00 2016-07-18 00:00:00
# 110 2013-02-15 00:00:00 2014-11-25 00:00:00
# 119 2013-07-02 00:00:00 2013-10-02 00:00:00
# 323 2015-06-18 00:00:00 2016-09-07 00:00:00
# 387 2018-05-29 00:00:00 2018-08-21 00:00:00
# 870 2017-06-14 00:00:00 2017-10-13 00:00:00
# 2526 2014-05-21 00:00:00 2016-10-12 00:00:00
# 2660 2018-07-03 00:00:00 2018-10-09 00:00:00
# 3079 2018-01-10 00:00:00 2020-08-17 00:00:00
# 3951 2017-01-11 00:00:00 2018-10-10 00:00:00
# 3995 2017-10-30 00:00:00 2018-08-30 00:00:00
# 5452 2015-06-18 00:00:00 2015-06-18 00:00:00
# 6077 2017-11-06 00:00:00 NaN
# 6162 2015-01-30 00:00:00 2015-07-20 00:00:00
# 6445 2015-12-03 00:00:00 2016-08-03 00:00:00
# 6955 2015-06-15 00:00:00 2016-01-25 00:00:00
# 7236 2016-08-19 00:00:00 2017-01-04 00:00:00
# 8024 2017-10-30 00:00:00 2018-01-29 00:00:00
# 8544 2018-02-07 00:00:00 2018-11-21 00:00:00
# 9048 2016-03-15 00:00:00 2016-09-19 00:00:00
# 9233 2015-01-30 00:00:00 2016-12-05 00:00:00
# 9888 2017-09-14 00:00:00 2020-08-12 00:00:00
# 10578 2016-08-31 00:00:00 2020-01-27 00:00:00
# 10945 2018-04-17 00:00:00 2019-12-12 00:00:00
# 11482 2016-02-08 00:00:00 2018-03-01 00:00:00
# 11595 2016-06-29 00:00:00 2017-10-25 00:00:00
# 11613 2016-08-17 00:00:00 2017-03-17 00:00:00
# 11649 2017-02-27 00:00:00 2017-12-11 00:00:00
# 11651 2018-06-13 00:00:00 2019-05-28 00:00:00
# 11859 2018-07-12 00:00:00 2018-07-12 00:00:00
# 11861 2018-04-06 00:00:00 2018-07-06 00:00:00
# 11933 2017-09-18 00:00:00 2018-03-12 00:00:00
# 12187 2015-11-05 00:00:00 2016-02-24 00:00:00
# 12208 2016-01-24 00:00:00 NaN
# 12275 2013-10-22 00:00:00 2016-12-29 00:00:00
# 12374 2017-10-02 00:00:00 2018-10-22 00:00:00
# 12426 2014-03-05 00:00:00 2015-05-12 00:00:00
# 12427 NaN 2020-07-22 00:00:00
# 12720 2012-10-31 00:00:00 NaN
# 13274 2018-04-03 00:00:00 2018-09-01 00:00:00
# 13609 2016-08-31 00:00:00 2018-04-23 00:00:00
# 13728 2017-02-24 00:00:00 2017-08-28 00:00:00
# 14846 2018-10-13 00:00:00 2018-10-13 00:00:00
# 15082 2016-03-16 00:00:00 2019-03-22 00:00:00
# 15202 2013-08-16 00:00:00 2016-12-08 00:00:00
# 15456 2013-10-21 00:00:00 2013-11-18 00:00:00
# 16116 2017-02-24 00:00:00 2017-08-23 00:00:00
# 16273 2018-03-12 00:00:00 2019-01-07 00:00:00
# 16477 2019-08-30 00:00:00 NaN
# 17206 2020-05-20 00:00:00 2020-08-24 00:00:00
# 17341 2018-01-02 00:00:00 2018-07-08 00:00:00
# 17419 2015-05-13 00:00:00 2016-08-24 00:00:00
# 17559 2015-07-27 00:00:00 2015-11-24 00:00:00
# 17638 2012-07-03 00:00:00 2014-09-09 00:00:00
# 18362 2018-05-31 00:00:00 2019-09-26 00:00:00
# 19342 2018-07-13 00:00:00 2019-01-01 00:00:00
# 19566 2017-01-30 00:00:00 2017-10-01 00:00:00
# 20270 2017-08-21 00:00:00 2018-03-12 00:00:00
# 20929 2016-09-29 00:00:00 2017-02-27 00:00:00
# 20930 2018-03-27 00:00:00 2018-09-18 00:00:00
# 21003 2016-08-31 00:00:00 2018-03-09 00:00:00
# 21389 2017-08-04 00:00:00 2020-07-23 00:00:00
# 21480 2017-01-11 00:00:00 2017-06-19 00:00:00
# 21543 2013-11-06 00:00:00 2014-05-05 00:00:00
# 21613 2016-12-22 00:00:00 2017-10-12 00:00:00
# 21655 2016-02-03 00:00:00 2016-05-31 00:00:00
# 21938 2018-04-12 00:00:00 2019-04-25 00:00:00
# 22100 2017-08-09 00:00:00 2018-01-17 00:00:00
# 22103 2017-10-09 00:00:00 2019-07-16 00:00:00
# 22129 2015-06-26 00:00:00 2017-03-22 00:00:00
# 22567 2018-04-16 00:00:00 2019-01-23 00:00:00
# 22676 2012-05-29 00:00:00 2012-10-03 00:00:00
# 22860 2017-06-09 00:00:00 2017-10-17 00:00:00
# 23559 2017-12-20 00:00:00 2019-08-27 00:00:00
# 23945 2017-10-31 00:00:00 2018-03-06 00:00:00
# 24143 2018-05-25 00:00:00 2019-04-15 00:00:00
# 24226 2017-01-18 00:00:00 2017-04-12 00:00:00
# 24383 2015-06-01 00:00:00 2015-12-14 00:00:00
# 24562 2018-06-01 00:00:00 2019-08-26 00:00:00
# 24582 2017-05-31 00:00:00 2019-02-27 00:00:00
# 24782 2018-06-22 00:00:00 2019-02-08 00:00:00
# 24830 2015-09-16 00:00:00 2017-06-05 00:00:00
# 25017 2012-02-28 00:00:00 2012-04-03 00:00:00
# 25882 2013-06-05 00:00:00 2015-03-25 00:00:00
# 26082 2018-03-30 00:00:00 2018-11-07 00:00:00
# 26152 2018-02-22 00:00:00 2018-03-22 00:00:00
# 26854 2018-01-30 00:00:00 2018-05-15 00:00:00
# 27180 2015-09-23 00:00:00 2016-02-16 00:00:00
# 27458 2016-07-15 00:00:00 2020-08-10 00:00:00
# 27543 2018-08-22 00:00:00 2018-11-14 00:00:00
# 27966 2014-05-01 00:00:00 2015-03-15 00:00:00
# 28445 2015-04-09 00:00:00 2017-01-31 00:00:00
# 28474 2014-05-05 00:00:00 2016-02-09 00:00:00
# 29307 2015-09-29 00:00:00 2015-12-29 00:00:00
# 29359 2017-08-25 00:00:00 2018-02-01 00:00:00
# 30078 2015-08-31 00:00:00 2019-05-20 00:00:00
# 30211 2015-07-09 00:00:00 NaN
# 30455 2015-01-23 00:00:00 2015-07-01 00:00:00
# 30492 2018-06-08 00:00:00 2018-09-07 00:00:00
# 30689 2018-02-21 00:00:00 2018-06-22 00:00:00
# 30997 2012-12-05 00:00:00 2013-05-15 00:00:00
# 31074 2018-08-03 00:00:00 2020-05-01 00:00:00
# 31131 2017-04-17 00:00:00 2017-09-06 00:00:00
# 31430 2016-03-04 00:00:00 2016-10-05 00:00:00
# 31676 2018-04-03 00:00:00 2019-01-28 00:00:00
# 32740 2014-03-12 00:00:00 2016-03-01 00:00:00
# 33531 2018-04-04 00:00:00 2020-02-24 00:00:00
# 33555 2014-06-01 00:00:00 NaN
# 33586 2019-07-08 00:00:00 2019-10-08 00:00:00
# 33871 2018-08-28 00:00:00 2020-07-14 00:00:00
# 34207 2018-02-01 00:00:00 2018-09-27 00:00:00
# 34807 2015-06-23 00:00:00 2015-10-20 00:00:00
# 35033 2012-11-26 00:00:00 2012-11-26 00:00:00
# 36062 2014-04-24 00:00:00 2016-06-07 00:00:00
# 36369 2016-01-07 00:00:00 2016-06-23 00:00:00
# 36508 2015-10-07 00:00:00 2016-07-11 00:00:00
# 36535 2017-08-09 00:00:00 2018-06-11 00:00:00

# %% [markdown]
# # Output and plot data <a class="anchor" id="fifth-bullet"></a>

# %%
df_results=pd.DataFrame(result_list)
df_results.columns=(['person_id', 'inital_ADT_start_date', 'inital_ADT_end_date'])

# %%
df_results
# Out:
#      person_id inital_ADT_start_date inital_ADT_end_date
# 0           12            2013-05-06          2013-05-06
# 1           18            2013-11-12          2014-03-13
# 2           25            2013-08-01          2014-02-18
# 3           26            2014-11-26          2016-09-14
# 4           38            2015-11-18          2016-07-18
# ..         ...                   ...                 ...
# 116      35033            2012-11-26          2012-11-26
# 117      36062            2014-04-24          2016-06-07
# 118      36369            2016-01-07          2016-06-23
# 119      36508            2015-10-07          2016-07-11
# 120      36535            2017-08-09          2018-06-11
#
# [121 rows x 3 columns]

# %%
#create a column for the time window 
df_results['Inital_ADT_timewindow'] = df_results['inital_ADT_end_date'] - df_results['inital_ADT_start_date']

# %%
#create a column for the inital adt use window as days
df_results['Inital_ADT_time_window_days']=df_results['Inital_ADT_timewindow'].dt.days

# %%
df_results
df_results['index1'] = df_results.index
df_results
# Out:
#      person_id inital_ADT_start_date inital_ADT_end_date  \
# 0           12            2013-05-06          2013-05-06
# 1           18            2013-11-12          2014-03-13
# 2           25            2013-08-01          2014-02-18
# 3           26            2014-11-26          2016-09-14
# 4           38            2015-11-18          2016-07-18
# ..         ...                   ...                 ...
# 116      35033            2012-11-26          2012-11-26
# 117      36062            2014-04-24          2016-06-07
# 118      36369            2016-01-07          2016-06-23
# 119      36508            2015-10-07          2016-07-11
# 120      36535            2017-08-09          2018-06-11
#
#     Inital_ADT_timewindow  Inital_ADT_time_window_days  index1
# 0                  0 days                          0.0       0
# 1                121 days                        121.0       1
# 2                201 days                        201.0       2
# 3                658 days                        658.0       3
# 4                243 days                        243.0       4
# ..                    ...                          ...     ...
# 116                0 days                          0.0     116
# 117              775 days                        775.0     117
# 118              168 days                        168.0     118
# 119              278 days                        278.0     119
# 120              306 days                        306.0     120
#
# [121 rows x 6 columns]

# %%
sns.set_style("darkgrid")
sns.set_context("poster", font_scale=1.2, rc={"lines.linewidth": 2})

ax = df_results.plot.bar(x='index1', y='Inital_ADT_time_window_days', width=0.8, color='pink', rot=90, figsize=(35, 5), legend=True, fontsize=12)

plt.tick_params(axis='x', labelsize=25)
plt.tick_params(axis='y', labelsize=25)

ax.set_xticks(np.arange(0, len(df_results.index)+1, 5))
ax.set_xticklabels(np.arange(0, len(df_results.index)+1, 5))

plt.xlabel("Patient count", fontsize=30, fontweight="bold")
plt.ylabel("Time (days)", fontsize=30,fontweight="bold")
plt.legend("")
plt.title("Inital ADT Use Duration",fontsize=30,fontweight="bold" )
#ax = df2[['index1'],['counts']].plot(kind='bar', title ="LoT", figsize=(30, 10), legend=True, fontsize=12)
# Out:
# Text(0.5, 1.0, 'Inital ADT Use Duration')

# %%
## sns.set_style("darkgrid")
sns.set_context("poster", font_scale=0.8, rc={"lines.linewidth": 2})
binsize=90

bins=np.arange(0, 1500, binsize)
fig, ax = plt.subplots(figsize = (8,5))

#n=df_results['Inital_ADT_time_window_days'].plot(kind = "hist", bins=bins, color="purple", alpha=0.5)
(n, bins, patches) = plt.hist(df_results['Inital_ADT_time_window_days'], bins=bins,color="purple", alpha=0.4)

#decorate
plt.title("binsize="+ str(binsize) +" days")
plt.xlabel("Days", fontsize=20, fontweight="bold",color="gray")
plt.ylabel("Population", fontsize=20,fontweight="bold", color="gray")

ax.set_xticks(np.arange(0, 1501, 180))
ax.set_xticklabels(np.arange(0, 1501, 180))

# plot the label/text to each bin
for i in range(0, len(n)):
    x_pos = (bins[i + 1] - bins[i])/4 + bins[i]
    y_pos = n[i] + 0.5
    label = str(int(n[i])) # relative frequency of each bin
    ax.text(x_pos, y_pos, label,fontsize=16,fontweight="bold",color="gray" )

# %%
df_results.to_csv("Inital_ADT_use_time_window_121pts_updated_Jan28.csv", encoding='utf-8', index=False)
